# %%
import time
import graph50 as g50
import graph100 as g100
import graph150 as g150
import graph200 as g200
import graph1000 as g1000

# %%
#graph size 50
g50 = g50.g
#graph size 100
g100 = g100.g
#graph size 150
g150 = g150.g
#graph size 200
g200 = g200.g
#graph size 1000
g1000 = g1000.g

# %%
#kruskal before with size 50
start_time = time.time()
g50.kruskal_merge()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V3,d=V4,w=3
# s=V32,d=V34,w=4
# s=V8,d=V10,w=5
# s=V29,d=V30,w=5
# s=V33,d=V34,w=6
# s=V24,d=V25,w=7
# s=V24,d=V26,w=8
# s=V30,d=V31,w=8
# s=V22,d=V23,w=12
# s=V10,d=V12,w=13
# s=V33,d=V31,w=14
# s=V13,d=V14,w=15
# s=V2,d=V4,w=16
# s=V4,d=V5,w=18
# s=V9,d=V10,w=20
# s=V12,d=V13,w=20
# s=V18,d=V19,w=20
# s=V14,d=V15,w=21
# s=V15,d=V16,w=21
# s=V18,d=V20,w=21
# s=V20,d=V22,w=21
# s=V27,d=V28,w=21
# s=V6,d=V7,w=21
# s=V4,d=V6,w=22
# s=V16,d=V18,w=23
# s=V28,d=V30,w=23
# s=V1,d=V2,w=27
# s=V11,d=V12,w=28
# s=V17,d=V18,w=28
# s=V26,d=V27,w=30
# s=V21,d=V22,w=31
# s=V23,d=V24,w=43
# Elapsed time: 0.002763986587524414 seconds

# %%
#kruskal before with size 100
start_time = time.time()
g100.kruskal_merge()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V21,d=V22,w=3
# s=V22,d=V24,w=3
# s=V25,d=V26,w=3
# s=V52,d=V53,w=3
# s=V42,d=V43,w=4
# s=V16,d=V18,w=7
# s=V12,d=V13,w=9
# s=V45,d=V46,w=11
# s=V15,d=V16,w=14
# s=V60,d=V62,w=14
# s=V26,d=V27,w=19
# s=V64,d=V65,w=19
# s=V31,d=V32,w=24
# s=V1,d=V3,w=25
# s=V36,d=V37,w=25
# s=V56,d=V57,w=27
# s=V14,d=V15,w=28
# s=V11,d=V12,w=30
# s=V33,d=V34,w=30
# s=V39,d=V40,w=31
# s=V8,d=V9,w=31
# s=V32,d=V34,w=33
# s=V5,d=V6,w=36
# s=V51,d=V52,w=37
# s=V19,d=V20,w=39
# s=V29,d=V30,w=39
# s=V48,d=V49,w=40
# s=V55,d=V56,w=40
# s=V28,d=V30,w=41
# s=V56,d=V58,w=41
# s=V46,d=V48,w=42
# s=V8,d=V10,w=43
# s=V41,d=V42,w=43
# s=V52,d=V54,w=43
# s=V60,d=V61,w=44
# s=V2,d=V4,w=46
# s=V50,d=V52,w=46
# s=V7,d=V8,w=47
# s=V27,d=V28,w=48
# s=V62,d=V63,w=48
# s=V6,d=V8,w=49
# s=V24,d=V25,w=51
# s=V37,d=V38,w=53
# s=V64,d=V66,w=53
# s=V18,d=V19,w=55
# s=V58,d=V60,w=55
# s=V16,d=V17,w=58
# s=V63,d=V64,w=60
# s=V20,d=V22,w=61
# s=V44,d=V45,w=63
# s=V30,d=V32,w=66
# s=V49,d=V50,w=68
# s=V12,d=V14,w=70
# ...

# %%
#kruskal before with size 150
start_time = time.time()
g150.kruskal_merge()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V39,d=V40,w=1
# s=V86,d=V88,w=1
# s=V15,d=V16,w=2
# s=V63,d=V64,w=3
# s=V28,d=V30,w=5
# s=V60,d=V61,w=6
# s=V96,d=V98,w=9
# s=V66,d=V67,w=11
# s=V58,d=V59,w=12
# s=V60,d=V62,w=12
# s=V69,d=V70,w=12
# s=V82,d=V84,w=14
# s=V88,d=V90,w=14
# s=V10,d=V12,w=15
# s=V52,d=V54,w=16
# s=V70,d=V71,w=16
# s=V14,d=V15,w=18
# s=V33,d=V34,w=19
# s=V66,d=V68,w=20
# s=V10,d=V11,w=21
# s=V100,d=V98,w=21
# s=V76,d=V77,w=22
# s=V78,d=V79,w=23
# s=V92,d=V93,w=23
# s=V31,d=V32,w=27
# s=V50,d=V52,w=30
# s=V48,d=V49,w=31
# s=V73,d=V74,w=31
# s=V35,d=V36,w=32
# s=V38,d=V39,w=32
# s=V46,d=V47,w=32
# s=V74,d=V75,w=32
# s=V92,d=V94,w=32
# s=V22,d=V23,w=33
# s=V37,d=V38,w=34
# s=V91,d=V92,w=34
# s=V1,d=V2,w=35
# s=V40,d=V41,w=35
# s=V4,d=V6,w=35
# s=V22,d=V24,w=38
# s=V24,d=V25,w=38
# s=V47,d=V48,w=38
# s=V36,d=V38,w=40
# s=V54,d=V56,w=40
# s=V12,d=V13,w=41
# s=V54,d=V55,w=41
# s=V71,d=V72,w=41
# s=V17,d=V18,w=42
# s=V83,d=V84,w=43
# s=V2,d=V4,w=44
# s=V77,d=V78,w=44
# s=V100,d=V99,w=44
# s=V19,d=V20,w=47
# ...

# %%
#kruskal before with size 200
start_time = time.time()
g200.kruskal_merge()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V100,d=V101,w=1
# s=V108,d=V109,w=2
# s=V4,d=V5,w=2
# s=V114,d=V115,w=3
# s=V35,d=V36,w=3
# s=V106,d=V108,w=4
# s=V14,d=V16,w=4
# s=V56,d=V58,w=4
# s=V104,d=V105,w=5
# s=V43,d=V44,w=7
# s=V85,d=V86,w=7
# s=V117,d=V118,w=8
# s=V126,d=V127,w=8
# s=V6,d=V8,w=10
# s=V131,d=V132,w=12
# s=V20,d=V21,w=13
# s=V10,d=V12,w=14
# s=V86,d=V87,w=15
# s=V54,d=V55,w=16
# s=V55,d=V56,w=19
# s=V16,d=V17,w=20
# s=V37,d=V38,w=20
# s=V59,d=V60,w=20
# s=V110,d=V111,w=21
# s=V84,d=V86,w=21
# s=V53,d=V54,w=22
# s=V122,d=V123,w=24
# s=V16,d=V18,w=25
# s=V65,d=V66,w=26
# s=V40,d=V41,w=27
# s=V96,d=V97,w=27
# s=V24,d=V26,w=29
# s=V28,d=V30,w=29
# s=V19,d=V20,w=30
# s=V40,d=V42,w=30
# s=V67,d=V68,w=30
# s=V38,d=V39,w=31
# s=V88,d=V90,w=32
# s=V99,d=V100,w=34
# s=V23,d=V24,w=35
# s=V109,d=V110,w=36
# s=V132,d=V134,w=37
# s=V51,d=V52,w=38
# s=V111,d=V112,w=39
# s=V31,d=V32,w=39
# s=V112,d=V113,w=43
# s=V64,d=V66,w=43
# s=V72,d=V73,w=43
# s=V128,d=V129,w=47
# s=V22,d=V23,w=47
# s=V114,d=V116,w=51
# ...

# %%
#kruskal before with size 1000
start_time = time.time()
g1000.kruskal_merge()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V660,d=V662,w=2
# s=V268,d=V270,w=5
# s=V352,d=V353,w=6
# s=V396,d=V397,w=7
# s=V438,d=V440,w=7
# s=V130,d=V131,w=8
# s=V116,d=V117,w=9
# s=V170,d=V171,w=11
# s=V42,d=V43,w=11
# s=V42,d=V44,w=13
# s=V451,d=V452,w=13
# s=V593,d=V594,w=14
# s=V296,d=V298,w=15
# s=V466,d=V467,w=15
# s=V91,d=V92,w=15
# s=V524,d=V525,w=19
# s=V149,d=V150,w=23
# s=V295,d=V296,w=23
# s=V147,d=V148,w=25
# s=V250,d=V251,w=26
# s=V570,d=V571,w=26
# s=V124,d=V126,w=28
# s=V648,d=V649,w=28
# s=V658,d=V660,w=28
# s=V503,d=V504,w=29
# s=V188,d=V190,w=30
# s=V24,d=V26,w=30
# s=V425,d=V426,w=33
# s=V140,d=V141,w=35
# s=V572,d=V573,w=35
# s=V160,d=V162,w=36
# s=V398,d=V400,w=36
# s=V167,d=V168,w=37
# s=V601,d=V602,w=37
# s=V642,d=V643,w=37
# s=V534,d=V535,w=39
# s=V312,d=V313,w=40
# s=V524,d=V526,w=41
# s=V549,d=V550,w=42
# s=V355,d=V356,w=43
# s=V269,d=V270,w=44
# s=V540,d=V542,w=45
# s=V32,d=V33,w=47
# s=V302,d=V303,w=52
# s=V36,d=V37,w=53
# s=V528,d=V530,w=53
# s=V650,d=V651,w=54
# s=V50,d=V51,w=58
# ...
