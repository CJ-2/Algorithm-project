# %%
import time
import graph50 as g50
import graph100 as g100
import graph150 as g150
import graph200 as g200
import graph1000 as g1000

# %%
#graph size 50
g50 = g50.g
#graph size 100
g100 = g100.g
#graph size 150
g150 = g150.g
#graph size 200
g200 = g200.g
#graph size 1000
g1000 = g1000.g

# %%
#kruskal after with size 50
start_time = time.time()
g50.kruskal_counting()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V24,d=V26,w=3
# s=V8,d=V10,w=4
# s=V11,d=V12,w=5
# s=V1,d=V2,w=6
# s=V26,d=V27,w=6
# s=V2,d=V3,w=9
# s=V25,d=V26,w=9
# s=V13,d=V14,w=10
# s=V10,d=V12,w=11
# s=V22,d=V23,w=11
# s=V20,d=V22,w=15
# s=V31,d=V32,w=15
# s=V9,d=V10,w=19
# s=V30,d=V31,w=19
# s=V32,d=V34,w=19
# s=V18,d=V20,w=20
# s=V14,d=V15,w=21
# s=V19,d=V20,w=21
# s=V6,d=V8,w=22
# s=V29,d=V30,w=23
# s=V4,d=V5,w=26
# s=V33,d=V34,w=26
# s=V12,d=V14,w=27
# s=V21,d=V22,w=32
# s=V26,d=V28,w=32
# s=V16,d=V17,w=33
# s=V7,d=V8,w=35
# s=V14,d=V16,w=35
# s=V4,d=V6,w=37
# s=V17,d=V18,w=41
# s=V28,d=V30,w=42
# s=V23,d=V24,w=49
# Elapsed time: 0.0033020973205566406 seconds

# %%
#kruskal after with size 100
start_time = time.time()
g100.kruskal_counting()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V8,d=V10,w=1
# s=V14,d=V15,w=2
# s=V39,d=V40,w=2
# s=V40,d=V41,w=3
# s=V18,d=V19,w=5
# s=V46,d=V47,w=5
# s=V12,d=V13,w=7
# s=V8,d=V9,w=8
# s=V60,d=V61,w=8
# s=V37,d=V38,w=9
# s=V3,d=V4,w=10
# s=V38,d=V40,w=10
# s=V58,d=V59,w=10
# s=V65,d=V63,w=10
# s=V11,d=V12,w=11
# s=V4,d=V6,w=12
# s=V57,d=V58,w=13
# s=V6,d=V8,w=14
# s=V42,d=V44,w=14
# s=V55,d=V56,w=14
# s=V64,d=V65,w=14
# s=V10,d=V12,w=17
# s=V53,d=V54,w=18
# s=V26,d=V28,w=21
# s=V26,d=V27,w=22
# s=V35,d=V36,w=23
# s=V36,d=V38,w=24
# s=V59,d=V60,w=24
# s=V32,d=V34,w=25
# s=V60,d=V62,w=25
# s=V16,d=V17,w=26
# s=V5,d=V6,w=27
# s=V54,d=V55,w=27
# s=V2,d=V4,w=28
# s=V31,d=V32,w=28
# s=V45,d=V46,w=30
# s=V43,d=V44,w=31
# s=V29,d=V30,w=32
# s=V15,d=V16,w=35
# s=V12,d=V14,w=39
# s=V16,d=V18,w=39
# s=V22,d=V23,w=39
# s=V48,d=V49,w=43
# s=V6,d=V7,w=44
# s=V64,d=V66,w=46
# s=V20,d=V21,w=50
# s=V52,d=V54,w=50
# s=V18,d=V20,w=51
# s=V25,d=V26,w=51
# s=V34,d=V35,w=51
# s=V50,d=V51,w=51
# s=V28,d=V30,w=58
# s=V51,d=V52,w=63
# ...

# %%
#kruskal after with size 150
start_time = time.time()
g150.kruskal_counting()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V44,d=V45,w=1
# s=V86,d=V87,w=1
# s=V28,d=V30,w=3
# s=V1,d=V2,w=4
# s=V88,d=V89,w=6
# s=V5,d=V6,w=10
# s=V86,d=V88,w=10
# s=V41,d=V42,w=12
# s=V14,d=V15,w=13
# s=V63,d=V64,w=13
# s=V70,d=V72,w=13
# s=V8,d=V10,w=14
# s=V32,d=V34,w=14
# s=V62,d=V63,w=14
# s=V38,d=V40,w=16
# s=V96,d=V97,w=17
# s=V33,d=V34,w=18
# s=V47,d=V48,w=21
# s=V78,d=V79,w=22
# s=V16,d=V17,w=23
# s=V24,d=V26,w=23
# s=V34,d=V35,w=23
# s=V98,d=V100,w=24
# s=V48,d=V50,w=31
# s=V59,d=V60,w=31
# s=V4,d=V6,w=32
# s=V60,d=V62,w=33
# s=V22,d=V24,w=34
# s=V30,d=V31,w=34
# s=V82,d=V83,w=34
# s=V35,d=V36,w=35
# s=V27,d=V28,w=36
# s=V60,d=V61,w=38
# s=V85,d=V86,w=38
# s=V11,d=V12,w=39
# s=V97,d=V98,w=39
# s=V28,d=V29,w=42
# s=V69,d=V70,w=42
# s=V68,d=V69,w=44
# s=V25,d=V26,w=45
# s=V42,d=V43,w=45
# s=V6,d=V7,w=47
# s=V36,d=V38,w=47
# s=V56,d=V58,w=47
# s=V77,d=V78,w=53
# s=V64,d=V65,w=55
# s=V84,d=V85,w=55
# s=V95,d=V96,w=56
# s=V18,d=V20,w=57
# s=V12,d=V14,w=58
# s=V82,d=V84,w=58
# s=V21,d=V22,w=59
# s=V50,d=V52,w=59
# ...

# %%
#kruskal after with size 200
start_time = time.time()
g200.kruskal_counting()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V9,d=V10,w=3
# s=V131,d=V132,w=6
# s=V51,d=V52,w=7
# s=V68,d=V70,w=10
# s=V92,d=V94,w=10
# s=V63,d=V64,w=11
# s=V49,d=V50,w=12
# s=V16,d=V17,w=13
# s=V101,d=V102,w=13
# s=V21,d=V22,w=15
# s=V46,d=V48,w=15
# s=V120,d=V122,w=15
# s=V130,d=V132,w=16
# s=V112,d=V113,w=17
# s=V65,d=V66,w=18
# s=V33,d=V34,w=19
# s=V26,d=V27,w=20
# s=V62,d=V63,w=20
# s=V10,d=V12,w=21
# s=V13,d=V14,w=21
# s=V97,d=V98,w=22
# s=V2,d=V3,w=23
# s=V80,d=V82,w=23
# s=V68,d=V69,w=24
# s=V102,d=V103,w=24
# s=V126,d=V128,w=24
# s=V111,d=V112,w=25
# s=V123,d=V124,w=25
# s=V89,d=V90,w=27
# s=V122,d=V124,w=27
# s=V124,d=V125,w=28
# s=V8,d=V9,w=29
# s=V34,d=V36,w=29
# s=V10,d=V11,w=30
# s=V116,d=V117,w=32
# s=V23,d=V24,w=36
# s=V53,d=V54,w=37
# s=V86,d=V87,w=38
# s=V90,d=V92,w=38
# s=V92,d=V93,w=38
# s=V42,d=V43,w=39
# s=V71,d=V72,w=44
# s=V72,d=V73,w=44
# s=V4,d=V5,w=48
# s=V32,d=V34,w=50
# s=V61,d=V62,w=51
# s=V91,d=V92,w=52
# s=V133,d=V134,w=52
# s=V12,d=V14,w=53
# s=V78,d=V80,w=53
# s=V52,d=V54,w=54
# ...

# %%
#kruskal after with size 1000
start_time = time.time()
g1000.kruskal_counting()
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# s=V477,d=V478,w=1
# s=V205,d=V206,w=2
# s=V333,d=V334,w=3
# s=V662,d=V663,w=4
# s=V161,d=V162,w=5
# s=V190,d=V191,w=5
# s=V450,d=V451,w=7
# s=V271,d=V272,w=8
# s=V392,d=V394,w=8
# s=V210,d=V212,w=9
# s=V241,d=V242,w=9
# s=V635,d=V636,w=9
# s=V373,d=V374,w=10
# s=V39,d=V40,w=11
# s=V175,d=V176,w=11
# s=V412,d=V413,w=11
# s=V154,d=V156,w=12
# s=V432,d=V433,w=12
# s=V296,d=V297,w=13
# s=V359,d=V360,w=15
# s=V566,d=V568,w=16
# s=V534,d=V536,w=17
# s=V61,d=V62,w=18
# s=V530,d=V532,w=20
# s=V448,d=V449,w=21
# s=V598,d=V599,w=23
# s=V336,d=V337,w=24
# s=V42,d=V43,w=26
# s=V625,d=V626,w=26
# s=V159,d=V160,w=27
# s=V277,d=V278,w=27
# s=V622,d=V623,w=27
# s=V481,d=V482,w=28
# s=V562,d=V564,w=28
# s=V43,d=V44,w=31
# s=V40,d=V41,w=32
# s=V272,d=V274,w=33
# s=V402,d=V404,w=35
# s=V530,d=V531,w=36
# s=V286,d=V287,w=39
# s=V169,d=V170,w=41
# s=V408,d=V409,w=41
# s=V192,d=V193,w=43
# s=V630,d=V631,w=44
# s=V45,d=V46,w=46
# s=V56,d=V57,w=46
# s=V72,d=V74,w=49
# s=V259,d=V260,w=49
# s=V46,d=V48,w=50
# ...
